# %%
import numpy as np
import librosa
import matplotlib.pyplot as plt

img_array = np.load('datasets/fsdd/spectrograms/0_lucas_25.wav.npy')
fig, ax = plt.subplots()
img = librosa.display.specshow(img_array,hop_length=256, x_axis='time',y_axis='log',ax=ax)
fig.colorbar(img, ax=ax)
